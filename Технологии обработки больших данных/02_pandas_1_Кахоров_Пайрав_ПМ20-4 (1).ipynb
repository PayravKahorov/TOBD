# %% [markdown]
# # Pandas (1)

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 2: Библиотека Pandas"
# * https://pandas.pydata.org/docs/user_guide/index.html#
# * https://pandas.pydata.org/docs/reference/index.html
# * Уэс Маккини. Python и анализ данных

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Загрузите данные из файла `sp500hst.txt` и обозначьте столбцы в соответствии с содержимым: `"date", "ticker", "open", "high", "low", "close", "volume"`.

# %%
import pandas as pd

df = pd.read_csv('sp500hst.txt', sep = ',', header = None,
           names = ["date", "ticker", "open", "high", "low", "close", "volume"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-745206a36d3a> in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('sp500hst.txt', sep = ',', header = None,
#       4            names = ["date", "ticker", "open", "high", "low", "close", "volume"])
#
# ...

# %%
import numpy as np
import random as rd

# %%
df.dtypes
# Out:
# date        int64
# ticker     object
# open      float64
# high      float64
# low       float64
# close     float64
# volume      int64
# dtype: object

# %% [markdown]
# 2. Рассчитайте среднее значение показателей для каждого из столбцов c номерами 3-6.

# %%
df.head(3)
# Out:
#        date ticker   open   high     low  close  volume
# 0  20090821      A  25.60  25.61  25.220  25.55   34758
# 1  20090824      A  25.64  25.74  25.330  25.50   22247
# 2  20090825      A  25.50  25.70  25.225  25.34   30891

# %%
df.mean()
# Out:
# date      2.009715e+07
# open      4.259546e+01
# high      4.310224e+01
# low       4.205446e+01
# close     4.260186e+01
# volume    8.139507e+04
# dtype: float64

# %%
df.iloc[:, 3:7].mean()
# Out:
# high         43.102243
# low          42.054464
# close        42.601865
# volume    81395.068138
# dtype: float64

# %% [markdown]
# 3. Добавьте столбец, содержащий только число месяца, к которому относится дата.

# %%
df['date'] = pd.to_datetime(df['date'], format = '%Y%m%d')
df.head()
df.dtypes
# Out:
# date      datetime64[ns]
# ticker            object
# open             float64
# high             float64
# low              float64
# close            float64
# volume             int64
# dtype: object

# %%
df['month'] = df['date'].dt.month
df.head()
# Out:
#         date ticker   open     high     low  close  volume  month
# 0 2009-08-21      A  25.60  25.6100  25.220  25.55   34758      8
# 1 2009-08-24      A  25.64  25.7400  25.330  25.50   22247      8
# 2 2009-08-25      A  25.50  25.7000  25.225  25.34   30891      8
# 3 2009-08-26      A  25.32  25.6425  25.145  25.48   33334      8
# 4 2009-08-27      A  25.50  25.5700  25.230  25.54   70176      8

# %% [markdown]
# ## Лабораторная работа №2.1

# %% [markdown]
# ### Базовые операции с `DataFrame`

# %% [markdown]
# 1.1 В файлах `recipes_sample.csv` и `reviews_sample.csv` находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца с индексами в таблице `reviews` (безымянный столбец).

# %%
recipes = pd.read_csv('recipes_sample.csv',sep = ',')
reviews = pd.read_csv('reviews_sample.csv',sep = ',')
reviews
# Out:
#         Unnamed: 0     user_id  recipe_id        date  rating  \
# 0           370476       21752      57993  2003-05-01       5
# 1           624300      431813     142201  2007-09-16       5
# 2           187037      400708     252013  2008-01-10       4
# 3           706134  2001852463     404716  2017-12-11       5
# 4           312179       95810     129396  2008-03-14       5
# ...            ...         ...        ...         ...     ...
# 126691     1013457     1270706     335534  2009-05-17       4
# 126692      158736     2282344       8701  2012-06-03       0
# 126693     1059834      689540     222001  2008-04-08       5
# 126694      453285  2000242659     354979  2015-06-02       5
# 126695      691207      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# ...

# %%
reviews_1 = reviews.rename(columns= {reviews.columns[0]: 'id'})
reviews_1
# Out:
#              id     user_id  recipe_id        date  rating  \
# 0        370476       21752      57993  2003-05-01       5
# 1        624300      431813     142201  2007-09-16       5
# 2        187037      400708     252013  2008-01-10       4
# 3        706134  2001852463     404716  2017-12-11       5
# 4        312179       95810     129396  2008-03-14       5
# ...         ...         ...        ...         ...     ...
# 126691  1013457     1270706     335534  2009-05-17       4
# 126692   158736     2282344       8701  2012-06-03       0
# 126693  1059834      689540     222001  2008-04-08       5
# 126694   453285  2000242659     354979  2015-06-02       5
# 126695   691207      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# 2       Very nice breakfast HH, easy to make and yummy...
# ...

# %% [markdown]
# 1.2 Для каждой из таблиц выведите основные параметры:
# * количество точек данных (строк);
# * количество столбцов;
# * тип данных каждого столбца.

# %%
print("{} - строк recipes, {} - строк reviews_1".format(recipes.shape[0],reviews_1.shape[0]))
print("{} - столбцов recipes, {} - столбцов reviews_1".format(recipes.shape[1],reviews_1.shape[1]))
# Out:
# 30000 - строк recipes, 126696 - строк reviews_1
# 8 - столбцов recipes, 6 - столбцов reviews_1

# %%
print(recipes.dtypes)
# Out:
# name               object
# id                  int64
# minutes             int64
# contributor_id      int64
# submitted          object
# n_steps           float64
# description        object
# n_ingredients     float64
# dtype: object

# %%
print(reviews.dtypes)
# Out:
# Unnamed: 0     int64
# user_id        int64
# recipe_id      int64
# date          object
# rating         int64
# review        object
# dtype: object

# %% [markdown]
# 1.3 Исследуйте, в каких столбцах таблиц содержатся пропуски. Посчитайте долю строк, содержащих пропуски, в отношении к общему количеству строк.

# %%
reviews_1.isna().sum(),recipes.isna().sum()
# Out:
# (id            0
#  user_id       0
#  recipe_id     0
#  date          0
#  rating        0
#  review       17
#  dtype: int64,
#  name                  0
#  id                    0
#  minutes               0
#  contributor_id        0
#  submitted             0
#  n_steps           11190
#  description         623
#  n_ingredients      8880
#  dtype: int64)

# %%
print((reviews_1['review'].isna().sum() * 100 /reviews_1['review'].shape)[0], '-%   | доля пропусков столбца review')
#
# Out:
# 0.013417945317926375 -%   | доля пропусков столбца review

# %%
recipes.isna().sum() * 100 / recipes.shape[0]
# Out:
# name               0.000000
# id                 0.000000
# minutes            0.000000
# contributor_id     0.000000
# submitted          0.000000
# n_steps           37.300000
# description        2.076667
# n_ingredients     29.600000
# dtype: float64

# %% [markdown]
# 1.4 Рассчитайте и выведите на экран среднее значение для каждого из числовых столбцов (где это имеет смысл).

# %%
recipes[['minutes','n_ingredients']].mean() # средние значения для данных recipes
# Out:
# minutes          123.358133
# n_ingredients      9.008286
# dtype: float64

# %%
reviews_1['rating'].mean() # среднее значение для review
# Out:
# 4.410802235271832

# %% [markdown]
# 1.5 Создайте и выведите на экран серию из 10 случайных названий рецептов.

# %%
rand_10 = np.random.randint(1,recipes.shape[0],10) 
recipes.iloc[rand_10] #для таблицы recipes
# Out:
#                                                   name      id  minutes  \
# 32               tastes like mounds bar    kahlua cake  129581      150
# 25126                              spanish rice pronto  100103       20
# 5687         chicken breasts with portabella mushrooms  399381       35
# 26612                        sweet and sour pork chops  370992       65
# 23720                    scrambled eggs   indian style  482989       25
# 927    apple pie filling   canned or you can freeze it  335405       50
# 12492                            grass roots fudge pie  380973       45
# 11716                              garbanzos y chorizo  320172       12
# 15730                   lebanese style fava bean pilaf  427634       40
# 661                                   amish baked corn  179128       55
#
#        contributor_id   submitted  n_steps  \
# 32             191220  2005-07-12     33.0
# 25126           25063  2004-09-17      NaN
# ...

# %%
reviews_1.iloc[rand_10] #для таблицы review
# Out:
#             id  user_id  recipe_id        date  rating  \
# 32      660094  2054214     352053  2011-11-05       5
# 25126   149981  1434684     318260  2009-11-02       0
# 5687    510246  1244045      89207  2009-10-02       5
# 26612  1020092   217226      49591  2005-10-02       4
# 23720  1050421   770898      23647  2008-03-02       5
# 927     310882   489552     113385  2013-10-23       5
# 12492  1046265   144204     104393  2008-01-13       4
# 11716   210673   180898      48364  2009-12-01       5
# 15730   711844   278118     348296  2010-05-14       4
# 661       9160   461834     456076  2011-11-09       5
#
#                                                   review
# 32     I live on this soup cold, with yogurt whipped ...
# 25126  Fabulous Vegetarian Recipe!!! Vegetarians can ...
# 5687     Great frosting. My hubby and daughter loved it!
# 26612  These are pretty good. They're not my favorite...
# 23720  No changes needed for this recipe,this is the ...
# ...

# %% [markdown]
# 1.6 Выведите на экран строку с __номером__ `54200`. Выведите на экран строку с __индексом__ `54200`.

# %%
reviews_1.iloc[54200]
# Out:
# id                                                      667742
# user_id                                                 813584
# recipe_id                                                  916
# date                                                2008-08-16
# rating                                                       5
# review       I've made this 3-4 times already and forgot to...
# Name: 54200, dtype: object

# %%
reviews_1.loc[54200]
# Out:
# id                                                      667742
# user_id                                                 813584
# recipe_id                                                  916
# date                                                2008-08-16
# rating                                                       5
# review       I've made this 3-4 times already and forgot to...
# Name: 54200, dtype: object

# %% [markdown]
# 1.7 Измените индекс в таблице `reviews`, пронумеровав строки, начиная с нуля.

# %%
reviews_1.set_index(np.arange(1,reviews_1.shape[0]+1))
# Out:
#              id     user_id  recipe_id        date  rating  \
# 1        370476       21752      57993  2003-05-01       5
# 2        624300      431813     142201  2007-09-16       5
# 3        187037      400708     252013  2008-01-10       4
# 4        706134  2001852463     404716  2017-12-11       5
# 5        312179       95810     129396  2008-03-14       5
# ...         ...         ...        ...         ...     ...
# 126692  1013457     1270706     335534  2009-05-17       4
# 126693   158736     2282344       8701  2012-06-03       0
# 126694  1059834      689540     222001  2008-04-08       5
# 126695   453285  2000242659     354979  2015-06-02       5
# 126696   691207      463435     415599  2010-09-30       5
#
#                                                    review
# 1       Last week whole sides of frozen salmon fillet ...
# 2       So simple and so tasty!  I used a yellow capsi...
# 3       Very nice breakfast HH, easy to make and yummy...
# ...

# %% [markdown]
# 1.8 Выведите информацию о рецептах, время выполнения которых не больше 20 минут и кол-во ингредиентов в которых не больше 5.

# %%
# recipes[((recipes['minutes'] < 20) & recipes['n_ingredients'] < 5)]
recipes[(recipes['minutes'] < 20) & (recipes['n_ingredients'] < 5)]
# Out:
#                                              name      id  minutes  \
# 90              hawaiian sunrise           mimosa  100837        5
# 91     tasty dish s   banana pudding in 2 minutes  286484        2
# 94                             1 minute meatballs   11361       13
# 143                             2 minute broccoli  256464        4
# 168                 3 ingredient moroccan dry rub  505748        3
# ...                                           ...     ...      ...
# 29817                           zen wine spritzer  498523        1
# 29858                        zesty stuffed olives  269904       10
# 29866                   zhanyshpa from kazakhstan  160599       15
# 29874                   ziplock vanilla ice cream   74250       10
# 29980        zucchini with jalapeno monterey jack  320622       10
#
#        contributor_id   submitted  n_steps  \
# 90              58104  2004-09-29      4.0
# 91              47892  2008-02-13      NaN
# ...

# %% [markdown]
# ### Работа с датами в `pandas`

# %% [markdown]
# 2.1 Преобразуйте столбец `submitted` из таблицы `recipes` в формат времени. Модифицируйте решение задачи 1.1 так, чтобы считать столбец сразу в нужном формате.

# %%
recipes[pd.to_datetime(recipes['submitted'], format = "%Y-%m-%d").dt.year > 2010]
# Out:
#                                           name      id  minutes  \
# 8           1 in canada chocolate chip cookies  453467       45
# 13     blepandekager   danish   apple pancakes  503475       50
# 36                       5 minute bread  pizza  487173       45
# 39          bacon cheeseburger and fries  soup  447429       60
# 47              full cool  macaroni and cheese  463219       25
# ...                                        ...     ...      ...
# 29959                     zucchini pizza boats  468144       35
# 29965               zucchini sausage casserole  472482       80
# 29976                            zucchini tots  505053       20
# 29994                           zuppa by luisa  464576       70
# 29998                              zydeco soup  486161       60
#
#        contributor_id   submitted  n_steps  \
# 8             1848091  2011-04-11     12.0
# 13             128473  2013-07-08     10.0
# 36            2406227  2012-09-19     30.0
# ...

# %%
recipes_2 = pd.read_csv('recipes_sample.csv',sep = ',',  parse_dates = ['submitted'])
recipes_2
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %%
# # recipes['year'] = pd.to_datetime(recipes['submitted']).dt.year
# # recipes
# recipes = recipes.drop(['year'] , axis = 1)
# recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25      NaN
# 1               91970  2003-07-26      NaN
# ...

# %% [markdown]
# 2.2 Выведите информацию о рецептах, добавленных в датасет не позже 2010 года.

# %%
recipes[pd.to_datetime(recipes['submitted'], format = "%Y-%m-%d").dt.year > 2010]
# Out:
#                                           name      id  minutes  \
# 8           1 in canada chocolate chip cookies  453467       45
# 13     blepandekager   danish   apple pancakes  503475       50
# 36                       5 minute bread  pizza  487173       45
# 39          bacon cheeseburger and fries  soup  447429       60
# 47              full cool  macaroni and cheese  463219       25
# ...                                        ...     ...      ...
# 29959                     zucchini pizza boats  468144       35
# 29965               zucchini sausage casserole  472482       80
# 29976                            zucchini tots  505053       20
# 29994                           zuppa by luisa  464576       70
# 29998                              zydeco soup  486161       60
#
#        contributor_id   submitted  n_steps  \
# 8             1848091  2011-04-11     12.0
# 13             128473  2013-07-08     10.0
# 36            2406227  2012-09-19     30.0
# ...

# %% [markdown]
# ### Работа со строковыми данными в `pandas`

# %% [markdown]
# 3.1  Добавьте в таблицу `recipes` столбец `description_length`, в котором хранится длина описания рецепта из столбца `description`.

# %%
recipes['description_length'] = recipes['description'].str.len()
recipes
# Out:
#                                                name      id  minutes  \
# 0             George s at the cove  black bean soup   44123       90
# 1                Healthy for them  yogurt popsicles   67664       10
# 2                      I can t believe it s spinach   38798       30
# 3                              Italian  gut busters   35173       45
# 4          Love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie s holey rustic olive and cheddar bread  267661       80
# 29996          Zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   Zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   Zydeco soup  486161       60
# 29999        Cookies by design   cookies on a stick  298512       29
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25      NaN
# 1               91970  2003-07-26      NaN
# ...

# %%
recipes['description'].str.split(' ').str.len()
# Out:
# 0         61.0
# 1         46.0
# 2          8.0
# 3         30.0
# 4        113.0
#          ...
# 29995     87.0
# 29996     51.0
# 29997     59.0
# 29998    122.0
# 29999     22.0
# Name: description, Length: 30000, dtype: float64

# %% [markdown]
# 3.2 Измените название каждого рецепта в таблице `recipes` таким образом, чтобы каждое слово в названии начиналось с прописной буквы.

# %%
recipes_1 = recipes
recipes_1['name'] = recipes['name'].str.capitalize()
recipes_1
# Out:
#                                                name      id  minutes  \
# 0             George s at the cove  black bean soup   44123       90
# 1                Healthy for them  yogurt popsicles   67664       10
# 2                      I can t believe it s spinach   38798       30
# 3                              Italian  gut busters   35173       45
# 4          Love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie s holey rustic olive and cheddar bread  267661       80
# 29996          Zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   Zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   Zydeco soup  486161       60
# 29999        Cookies by design   cookies on a stick  298512       29
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25      NaN
# 1               91970  2003-07-26      NaN
# ...

# %% [markdown]
# 3.3 Добавьте в таблицу `recipes` столбец `name_word_count`, в котором хранится количество слов из названии рецепта (считайте, что слова в названии разделяются только пробелами). Обратите внимание, что между словами может располагаться несколько пробелов подряд.

# %%
recipes_1['name_word_count'] = recipes['name'].str.split().str.len()
recipes_1
# Out:
#                                                name      id  minutes  \
# 0             George s at the cove  black bean soup   44123       90
# 1                Healthy for them  yogurt popsicles   67664       10
# 2                      I can t believe it s spinach   38798       30
# 3                              Italian  gut busters   35173       45
# 4          Love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie s holey rustic olive and cheddar bread  267661       80
# 29996          Zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   Zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   Zydeco soup  486161       60
# 29999        Cookies by design   cookies on a stick  298512       29
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25      NaN
# 1               91970  2003-07-26      NaN
# ...
